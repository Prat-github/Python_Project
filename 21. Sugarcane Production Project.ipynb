# %%
#Importing useful libraries

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("List of Countries by Sugarcane Production.csv")

# %%
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America       768.678.382                  3.668,531
# 1     India           Asia       348.448.000                     260721
# 2     China           Asia       123.059.739                      88287
# 3  Thailand           Asia        87.468.496                  1.264,303
# 4  Pakistan           Asia        65.450.704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0        10.226.205             75.167,5
# 1         4.950.000             70.393,5
# 2         1.675.215             73.459,1
# 3         1.336.575             65.442,2
# 4         1.130.820               57.879

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Country                     103 non-null    object
#  1   Continent                   103 non-null    object
#  2   Production (Tons)           103 non-null    object
#  3   Production per Person (Kg)  103 non-null    object
#  4   Acreage (Hectare)           102 non-null    object
#  5   Yield (Kg / Hectare)        102 non-null    object
# dtypes: object(6)
# memory usage: 5.0+ KB

# %% [markdown]
# # Data cleaning

# %%
df["Production (Tons)"] = df["Production (Tons)"].str.replace(".","")
df["Production per Person (Kg)"] = df["Production per Person (Kg)"].str.replace(".","").str.replace(",","")
df["Acreage (Hectare)"] = df["Acreage (Hectare)"].str.replace(".","")
df["Yield (Kg / Hectare)"] = df["Yield (Kg / Hectare)"].str.replace(".","").str.replace(",","")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19516\560015425.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Production (Tons)"] = df["Production (Tons)"].str.replace(".","")
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19516\560015425.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Production per Person (Kg)"] = df["Production per Person (Kg)"].str.replace(".","").str.replace(",","")
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19516\560015425.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
df.rename(columns= {"Production (Tons)": "Production(Tons)"}, inplace = True)
df.rename(columns= {"Production per Person (Kg)": "Production_per_person(Kg)"}, inplace = True)
df.rename(columns= {"Acreage (Hectare)": "Acreage(Hectare)"}, inplace = True)
df.rename(columns= {"Yield (Kg / Hectare)": "Yield(Kg/Hectare)"}, inplace = True)

# %%
df.head()
# Out:
#     Country      Continent Production(Tons) Production_per_person(Kg)  \
# 0    Brazil  South America        768678382                   3668531
# 1     India           Asia        348448000                    260721
# 2     China           Asia        123059739                     88287
# 3  Thailand           Asia         87468496                   1264303
# 4  Pakistan           Asia         65450704                    324219
#
#   Acreage(Hectare) Yield(Kg/Hectare)
# 0         10226205            751675
# 1          4950000            703935
# 2          1675215            734591
# 3          1336575            654422
# 4          1130820             57879

# %%
df.isna().sum()
# Out:
# Country                      0
# Continent                    0
# Production(Tons)             0
# Production_per_person(Kg)    0
# Acreage(Hectare)             1
# Yield(Kg/Hectare)            1
# dtype: int64

# %%
df = df.dropna().reset_index().drop("index", axis = 1)
df
# Out:
#        Country      Continent Production(Tons) Production_per_person(Kg)  \
# 0       Brazil  South America        768678382                   3668531
# 1        India           Asia        348448000                    260721
# 2        China           Asia        123059739                     88287
# 3     Thailand           Asia         87468496                   1264303
# 4     Pakistan           Asia         65450704                    324219
# ..         ...            ...              ...                       ...
# 97       Spain         Europe              394                         8
# 98     Lebanon           Asia               97                        16
# 99   Singapore           Asia               50                         9
# 100      Samoa        Oceania               12                         6
# 101      Syria           Asia                1                         0
#
#     Acreage(Hectare) Yield(Kg/Hectare)
# 0           10226205            751675
# ...

# %%
df.isna().sum()
# Out:
# Country                      0
# Continent                    0
# Production(Tons)             0
# Production_per_person(Kg)    0
# Acreage(Hectare)             0
# Yield(Kg/Hectare)            0
# dtype: int64

# %%
df.nunique()
# Out:
# Country                      102
# Continent                      6
# Production(Tons)             102
# Production_per_person(Kg)    101
# Acreage(Hectare)             101
# Yield(Kg/Hectare)            102
# dtype: int64

# %%
df.dtypes
# Out:
# Country                      object
# Continent                    object
# Production(Tons)             object
# Production_per_person(Kg)    object
# Acreage(Hectare)             object
# Yield(Kg/Hectare)            object
# dtype: object

# %%
df["Production(Tons)"] = df["Production(Tons)"].astype(float)
df["Production_per_person(Kg)"] = df["Production_per_person(Kg)"].astype(float)
df["Acreage(Hectare)"] = df["Acreage(Hectare)"].astype(float)
df["Yield(Kg/Hectare)"] = df["Yield(Kg/Hectare)"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Country                    102 non-null    object
#  1   Continent                  102 non-null    object
#  2   Production(Tons)           102 non-null    float64
#  3   Production_per_person(Kg)  102 non-null    float64
#  4   Acreage(Hectare)           102 non-null    float64
#  5   Yield(Kg/Hectare)          102 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 4.9+ KB

# %% [markdown]
# # Univariate Analysis

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_person(Kg)  \
# 0    Brazil  South America       768678382.0                  3668531.0
# 1     India           Asia       348448000.0                   260721.0
# 2     China           Asia       123059739.0                    88287.0
# 3  Thailand           Asia        87468496.0                  1264303.0
# 4  Pakistan           Asia        65450704.0                   324219.0
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0           751675.0
# 1         4950000.0           703935.0
# 2         1675215.0           734591.0
# 3         1336575.0           654422.0
# 4         1130820.0            57879.0

# %% [markdown]
# # How many countries produce sugarcane from each continent?

# %%
df["Continent"].value_counts()
# Out:
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: Continent, dtype: int64

# %%
df["Continent"].value_counts().plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking outliers

# %%
plt.figure(figsize = (12,8))

plt.subplot(2,2,1)
sns.boxplot(df["Production(Tons)"])
plt.title("Production(Ton)")

plt.subplot(2,2,2)
sns.boxplot(df["Production_per_person(Kg)"])
plt.title("Production_per_person")

plt.subplot(2,2,3)
sns.boxplot(df["Acreage(Hectare)"])
plt.title("Acreage(Hectare)")

plt.subplot(2,2,4)
sns.boxplot(df["Yield(Kg/Hectare)"])
plt.title("Yield(Kg/Hectare)")
# Out:
# Text(0.5, 1.0, 'Yield(Kg/Hectare)')

# %% [markdown]
# We have outliers in the data but outliers are possible here as it shows the countries which has maximum production.

# %% [markdown]
# # Distribution of the columns

# %%
plt.figure(figsize = (12,8))

plt.subplot(2,2,1)
sns.distplot(df["Production(Tons)"])

plt.subplot(2,2,2)
sns.distplot(df["Production_per_person(Kg)"])

plt.subplot(2,2,3)
sns.distplot(df["Acreage(Hectare)"])

plt.subplot(2,2,4)
sns.distplot(df["Yield(Kg/Hectare)"])
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19516\2668897985.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Production(Tons)"])
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19516\2668897985.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# # Bivariate Analysis

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_person(Kg)  \
# 0    Brazil  South America       768678382.0                  3668531.0
# 1     India           Asia       348448000.0                   260721.0
# 2     China           Asia       123059739.0                    88287.0
# 3  Thailand           Asia        87468496.0                  1264303.0
# 4  Pakistan           Asia        65450704.0                   324219.0
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0           751675.0
# 1         4950000.0           703935.0
# 2         1675215.0           734591.0
# 3         1336575.0           654422.0
# 4         1130820.0            57879.0

# %% [markdown]
# # Which country produces maximum sugarcane?

# %%
df_new = df[["Country" , "Production(Tons)"]].set_index("Country")
df_new
# Out:
#            Production(Tons)
# Country
# Brazil          768678382.0
# India           348448000.0
# China           123059739.0
# Thailand         87468496.0
# Pakistan         65450704.0
# ...                     ...
# Spain                 394.0
# Lebanon                97.0
# Singapore              50.0
# Samoa                  12.0
# Syria                   1.0
#
# [102 rows x 1 columns]

# %%
df_new["Production(Tons)_Percent"] = (df_new["Production(Tons)"] / df_new["Production(Tons)"].sum())*100
df_new
# Out:
#            Production(Tons)  Production(Tons)_Percent
# Country
# Brazil          768678382.0              4.072729e+01
# India           348448000.0              1.846200e+01
# China           123059739.0              6.520138e+00
# Thailand         87468496.0              4.634389e+00
# Pakistan         65450704.0              3.467809e+00
# ...                     ...                       ...
# Spain                 394.0              2.087551e-05
# Lebanon                97.0              5.139401e-06
# Singapore              50.0              2.649176e-06
# Samoa                  12.0              6.358022e-07
# Syria                   1.0              5.298352e-08
#
# [102 rows x 2 columns]

# %%
plt.figure(figsize = (5,3))
df_new["Production(Tons)_Percent"].head(5).plot(kind = "pie" , autopct = "%.2f")
# Out:
# <AxesSubplot:ylabel='Production(Tons)_Percent'>

# %%
plt.figure(figsize = (6,3))
df[["Country" , "Production(Tons)"]].head(10).set_index("Country").sort_values("Production(Tons)", ascending= False).plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
sns.barplot(data = df.head(10), x = "Country", y = "Production(Tons)")
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# # Which country has highest land?

# %%
df_acr = df.sort_values("Acreage(Hectare)" , ascending = False).head(15)
sns.barplot(data = df_acr ,  x ="Country", y = "Acreage(Hectare)")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Which country has highest yield per hectare?

# %%
df_yld = df.sort_values("Yield(Kg/Hectare)" , ascending = False).head(15)
sns.barplot(data = df_yld , x = "Country", y = "Yield(Kg/Hectare)")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Which country has highest production?

# %%
df_prd = df.sort_values("Production_per_person(Kg)" , ascending = False).head(15)
sns.barplot(data = df_prd , x = "Country", y = "Production_per_person(Kg)")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19516\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                            Production(Tons)  Production_per_person(Kg)  \
# Production(Tons)                   1.000000                   0.352369
# Production_per_person(Kg)          0.352369                   1.000000
# Acreage(Hectare)                   0.997550                   0.341974
# Yield(Kg/Hectare)                  0.121125                   0.226719
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)
# Production(Tons)                   0.997550           0.121125
# Production_per_person(Kg)          0.341974           0.226719
# Acreage(Hectare)                   1.000000           0.107826
# Yield(Kg/Hectare)                  0.107826           1.000000

# %%
sns.heatmap( data = df.corr(), annot = True, cmap = "Greens")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19516\2709620638.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap( data = df.corr(), annot = True, cmap = "Greens")
# <AxesSubplot:>

# %% [markdown]
# # Do countries with highest land produce more sugarcane?

# %%
plt.figure(figsize =(6,4))
sns.scatterplot(data = df, x = "Acreage(Hectare)", y = "Production(Tons)")
# Out:
# <AxesSubplot:xlabel='Acreage(Hectare)', ylabel='Production(Tons)'>

# %% [markdown]
# # Do countries which yield more sugarcane per hectare produces more sugarcane in total?

# %%
plt.figure(figsize =(6,4))
sns.scatterplot(data = df, x = "Yield(Kg/Hectare)" , y = "Production(Tons)", hue = "Continent")
# Out:
# <AxesSubplot:xlabel='Yield(Kg/Hectare)', ylabel='Production(Tons)'>

# %% [markdown]
# # Analysis for Continent

# %%
df_continent = df.groupby("Continent").sum()
df_continent
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19516\535892637.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_continent = df.groupby("Continent").sum()
#                Production(Tons)  Production_per_person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                 10144110.0         1439089.0
# Asia                721930425.0                  3120808.0        10608319.0
# Europe                   5823.0                      536.0              71.0
# North America       173995947.0                 15420953.0         1581983.0
# Oceania              36177574.0                  3158066.0          490909.0
# South America       865588126.0                 10228540.0        11369236.0
#
#                Yield(Kg/Hectare)
# Continent
# ...

# %%
df_continent["no_of_countries"] = df.groupby("Continent").count()["Country"]
df_continent
# Out:
#                Production(Tons)  Production_per_person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                 10144110.0         1439089.0
# Asia                721930425.0                  3120808.0        10608319.0
# Europe                   5823.0                      536.0              71.0
# North America       173995947.0                 15420953.0         1581983.0
# Oceania              36177574.0                  3158066.0          490909.0
# South America       865588126.0                 10228540.0        11369236.0
#
#                Yield(Kg/Hectare)  no_of_countries
# Continent
# Africa                20700454.0               38
# Asia                  11197308.0               25
# Europe                 1318709.0                2
# North America          9581162.0               22
# Oceania                1624191.0                4
# South America          6766896.0               11

# %% [markdown]
# #  Which continent produces maximum sugarcane?

# %%
df_continent["Production(Tons)"].sort_values( ascending = False).plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='Continent'>

# %% [markdown]
# # Do number of countries in a Continent effects production of sugarcane?

# %%
df_continent
# Out:
#                Production(Tons)  Production_per_person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                 10144110.0         1439089.0
# Asia                721930425.0                  3120808.0        10608319.0
# Europe                   5823.0                      536.0              71.0
# North America       173995947.0                 15420953.0         1581983.0
# Oceania              36177574.0                  3158066.0          490909.0
# South America       865588126.0                 10228540.0        11369236.0
#
#                Yield(Kg/Hectare)  no_of_countries
# Continent
# Africa                20700454.0               38
# Asia                  11197308.0               25
# Europe                 1318709.0                2
# North America          9581162.0               22
# Oceania                1624191.0                4
# South America          6766896.0               11

# %%
sns.lineplot(data = df_continent, x = "no_of_countries" ,  y = "Production(Tons)")
# Out:
# <AxesSubplot:xlabel='no_of_countries', ylabel='Production(Tons)'>

# %%
df_continent.reset_index(inplace = True)
sns.lineplot(data = df_continent.sort_values("no_of_countries", ascending = True), x = "Continent" ,  y = "Production(Tons)")
plt.xticks(rotation = "vertical")
plt.show()

# %%
sns.lineplot(data = df_continent.sort_values("no_of_countries", ascending = True), x = "no_of_countries" ,  y = "Production(Tons)")
plt.xticks(ticks = df_continent["no_of_countries"], labels = df_continent["Continent"] , rotation = "vertical")
plt.show()

# %% [markdown]
# # Do continent with highest land produces more sugarcane?

# %%
df_continent.corr()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19516\1657688773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_continent.corr()
#                            Production(Tons)  Production_per_person(Kg)  \
# Production(Tons)                   1.000000                   0.143100
# Production_per_person(Kg)          0.143100                   1.000000
# Acreage(Hectare)                   0.994897                   0.073059
# Yield(Kg/Hectare)                  0.104312                   0.514924
# no_of_countries                    0.109244                   0.526387
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)  \
# Production(Tons)                   0.994897           0.104312
# Production_per_person(Kg)          0.073059           0.514924
# ...

# %%
sns.lineplot(data = df_continent, x = "Acreage(Hectare)", y = "Production(Tons)" )
# Out:
# <AxesSubplot:xlabel='Acreage(Hectare)', ylabel='Production(Tons)'>

# %%
# Setting index back to continent so that it could be displayed in Piechart
df_continent.set_index("Continent", inplace=True)

# %% [markdown]
# # Production distribution by continent

# %%
df_continent["Production(Tons)"].plot(kind = "pie", autopct = "%.2f")
# Out:
# <AxesSubplot:ylabel='Production(Tons)'>

# %%
df_continent
# Out:
#                Production(Tons)  Production_per_person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                 10144110.0         1439089.0
# Asia                721930425.0                  3120808.0        10608319.0
# Europe                   5823.0                      536.0              71.0
# North America       173995947.0                 15420953.0         1581983.0
# Oceania              36177574.0                  3158066.0          490909.0
# South America       865588126.0                 10228540.0        11369236.0
#
#                Yield(Kg/Hectare)  no_of_countries
# Continent
# Africa                20700454.0               38
# Asia                  11197308.0               25
# Europe                 1318709.0                2
# North America          9581162.0               22
# Oceania                1624191.0                4
# South America          6766896.0               11
